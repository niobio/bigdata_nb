# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data/opendata_2014_naixements-taxes.csv', sep=';')
df.head()
# Out:
#    DTE                                    BARRIS TAXAPERMILHABITANTS
# 0  NaN                                       NaN    8,36003310063867
# 1    1                               1. el Raval    8,97049843121565
# 2    1                         2. el Barri Gòtic    6,16499300877081
# 3    1                         3. la Barceloneta    5,89247881355932
# 4    1  4. Sant Pere, Santa Caterina i la Ribera    7,46936219697647
#
# [5 rows x 3 columns]

# %%
df2 = df.drop("DTE", axis=1)
df2
# Out:
#                                           BARRIS TAXAPERMILHABITANTS
# 0                                            NaN    8,36003310063867
# 1                                    1. el Raval    8,97049843121565
# 2                              2. el Barri Gòtic    6,16499300877081
# 3                              3. la Barceloneta    5,89247881355932
# 4       4. Sant Pere, Santa Caterina i la Ribera    7,46936219697647
# 5                               5. el Fort Pienc    8,19203657839588
# 6                          6. la Sagrada Família     8,4407103452309
# 7                      7. la Dreta de l Eixample    8,12182741116751
# 8             8. l Antiga Esquerra de l Eixample    7,91044418342642
# 9              9. la Nova Esquerra de l Eixample    7,75785765112203
# 10                               10. Sant Antoni    7,71734565308694
# 11              11. el Poble Sec - Parc Montjuïc    8,88822682357615
# 12  12. la Marina del Prat Vermell - Zona Franca    10,4895104895105
# ...

# %%
import pickle

# %%
arb = pickle.load( open( "arbres.pkl", "rb" ) )

# %%
arb.head()
# Out:
#       id          posicioX          posicioY  \
# 0  24838  430639.138486028  4587803.20190948
# 1  24844  430616.306474978   4587806.4110877
# 2  29604  428535.285878997  4581299.73478935
# 3  39485  428793.407717021  4581225.64271597
# 4  42691  433516.857016434  4585967.12222804
#
#                                            espaiVerd             adreca  \
# 0  Valldaura, Pg. (Llucmajor, Pl. - Fabra i Puig,...  Pg Valldaura, 184
# 1  Valldaura, Pg. (Llucmajor, Pl. - Fabra i Puig,...  Pg Valldaura, 180
# 2                      Llançà (València - Roma, Av.)      C\ Llança, 37
# 3                                    Joan Miró, Parc  Parc Joan Miró, 0
# 4                  Prim, Rbla. (Guipúscoa - Binefar)     Rbla Prim, 167
#
#      alcada             nomCientific          nomEsp                  nomCat  \
# 0  EXEMPLAR  Populus nigra 'Italica'  Chopo lombardo        Pollancre gavatx
# 1  EXEMPLAR  Populus nigra 'Italica'  Chopo lombardo        Pollancre gavatx
# ...

# %%
import cPickle as pickle
